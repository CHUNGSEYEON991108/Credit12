# %% [markdown]
# <a href="https://colab.research.google.com/github/CHUNGSEYEON991108/Credit12/blob/main/20240927_Model_2_feedback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #딥러닝 모델을 만든 이유(피드백): 신용카드 이상거래가 데이터상에서 측정되어, 딥러닝 모델을 활용하여 효과적으로 신용카드 이상거래를 탐지 하기 위함

# %% [markdown]
# #Module

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from google.colab import drive
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from sklearn.metrics import recall_score, confusion_matrix, accuracy_score, classification_report, roc_curve, auc, roc_auc_score
from imblearn.over_sampling import SMOTE # For Oversampling
from sklearn.preprocessing import MinMaxScaler # Data Normalization (각 특징에 대해 0~1 사이 값으로 변환)
from sklearn.model_selection import StratifiedKFold #TrainData, TestData 분리(K-fold)
from sklearn.model_selection import train_test_split #피드백으로 추가한 부분

# %% [markdown]
# # Data Load

# %%
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Detect credit card anomalies/creditcard.csv'
data = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # EDA

# %%
# data.info() #결측치 없음
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # 원본 데이터 시각화

# %%
amount_original = data['Amount'].values
time_original = data['Time'].values

plt.subplots(constrained_layout=True)

plt.subplot(2, 1, 1)
plt.title('Transaction Amount Distribution')
plt.hist(amount_original, bins=50)

plt.subplot(2, 1, 2)
plt.title('Transaction Time Distribution')
plt.hist(time_original, bins=50)

plt.show()
# Out:
# <ipython-input-4-993f4f3db8c2>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 1, 1)

# %% [markdown]
# # TrainData TestData 분리, Oversampling, Data Normalization

# %% [markdown]
# ##Kfold 할때 test셋을 먼저 빼놓고 나머지 80으로 kfold했어야한다(Training Data를 만들었어야만 했다).

# %%
# 1. X, y 분리
X= data.iloc[:, :-1] # Time~Amount
Y= data.iloc[:, -1] # Class

# 2. 데이터 정규화 (각 특징에 대해 0~1 사이 값으로 변환), 데이터 분리전 데이터 정규화를 하도록 코드 순서 변경(피드백)
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X) # X데이터를 scaling
X = pd.DataFrame(X_scaled, index=X.index, columns=X.columns) # X_scaled는 numpy이므로 DataFrame으로 변경

# 3. Train Data와 Test Data 분리(피드백으로 추가한 부분)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# 4. Oversampling(피드백으로 Oversampling 알고리즘 변경
smote = SMOTE(random_state=0)
X_resampled, Y_resampled = smote.fit_resample(X_train, y_train)

# 5. train, test 분리
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 0)

for train_index, val_index in kfold.split(X_resampled, Y_resampled):
    X_train, X_val = X_resampled.iloc[train_index], X_resampled.iloc[val_index]
    y_train, y_val = Y_resampled.iloc[train_index], Y_resampled.iloc[val_index]

print(X_train.shape, y_train.shape) #(363904, 30) (363904,) 80% (Test_Set 없음)
print(X_val.shape, y_val.shape) #(90976, 30) (90976,) 20% (Test_Set 없음)
# Out:
# (363904, 30) (363904,)
# (90976, 30) (90976,)

# %%
Y_resampled.value_counts() #Over Sampling check, 피드백대로 수정한 결과 28만개에서 22만개로 감소
# Out:
# Class
# 0    227440
# 1    227440
# Name: count, dtype: int64

# %% [markdown]
# # 정규화된 데이터 시각화

# %%
amount_normalized = X['Amount'].values
time_normalized = X['Time'].values

plt.subplots(constrained_layout=True)

plt.subplot(2, 1, 1)
plt.title('Transaction Amount Distribution')
plt.hist(amount_normalized, bins=50)

plt.subplot(2, 1, 2)
plt.title('Transaction Time Distribution')
plt.hist(time_normalized, bins=50)

plt.show()
# Out:
# <ipython-input-11-174f209d2bbb>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 1, 1)

# %% [markdown]
# # Hyperparameter

# %% [markdown]
# ## learning_rate_decay 변경
#      exponential -> cosine -> inverse

# %% [markdown]
# ##EXP(Learning_Rate_Decay)

# %%
# 초기값 설정
initial_learning_rate = 0.01
decay_steps = 5
decay_rate = 0.95
epochs = np.arange(1, 101)

#Exponential Decay
exponential_decay = tf.keras.optimizers.schedules.ExponentialDecay(
     initial_learning_rate, decay_steps=decay_steps, decay_rate=decay_rate
 )


# 2. 배치크기
batch_size = 2**12 #13만 #train 데이터의 약 50%크기

# %% [markdown]
# ##Cosine Decay(Learning_Rate_Decay)

# %%
#Cosine Decay
CosineDecayValue=tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=0.01,
    decay_steps=100,
    alpha=0.001,
    # name='CosineDecay',
    warmup_target=None,
    warmup_steps=0
)
epochs = np.arange(1, 101)

# 2. 배치크기
batch_size = 2**12 #13만 #train 데이터의 약 50%크기

# %% [markdown]
# ##Inverse(Learning_Rate_Decay)

# %%
#Inverse
InverseValue=tf.keras.optimizers.schedules.InverseTimeDecay(
    initial_learning_rate=0.01,
    decay_steps=20,
    decay_rate=0.95,
    staircase=False,
    name='InverseTimeDecay'
)
epochs = np.arange(1, 101)

# 2. 배치크기
batch_size = 2**12 #13만 #train 데이터의 약 50%크기

# %% [markdown]
# ## Learning Rate Decay Visualization

# %%
# Learning_Rate 체크
learning_rate_check = []
for epoch in epochs:
    learning_rate = InverseValue(epoch)
    learning_rate_check.append(learning_rate.numpy())

# 학습율 시각화
plt.figure(figsize=(8, 6))
plt.plot(epochs, learning_rate_check, label='Learning Rate')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.title('Learning Rate over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Model 구축

# %% [markdown]
# ## Model 초기화

# %%
print(X_train.shape[1])
# Out:
# 30

# %%
model = Sequential()

#가중치 초기화(Weight Initailization)
# weight_init = tf.keras.initializers.he_uniform()
# weight_init = tf.keras.initializers.RandomNormal()
weight_init = tf.keras.initializers.glorot_uniform()

#model.add(Input(shape=(X_train.shape[1],)))
model.add(Dense(128, activation='relu', input_dim=30, kernel_initializer=weight_init))  # 첫 번째 은닉층
model.add(Dropout(0.5)) # 50% 드롭아웃 적용
model.add(Dense(64, activation='relu',kernel_initializer=weight_init))  # 두 번째 은닉층
model.add(Dropout(0.5))  # 50% 드롭아웃 적용
model.add(Dense(32, activation='relu',kernel_initializer=weight_init)) # 세 번째 은닉층
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 128)                 │           3,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,337 (56.00 KB)
#  Trainable params: 14,337 (56.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Model Complie

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=InverseValue),
              loss = 'binary_crossentropy',
              metrics = ['recall'])

# %% [markdown]
# # Model Training

# %%
#생성된 데이터를 batch_size로 나누어, epoch만큼 학습시킴
history = model.fit(X_train, y_train, epochs=len(epochs), validation_data=(X_val, y_val), batch_size = batch_size)
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.3387 - recall: 0.7934 - val_loss: 0.1443 - val_recall: 0.9047
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1541 - recall: 0.9139 - val_loss: 0.1312 - val_recall: 0.9140
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1419 - recall: 0.9218 - val_loss: 0.1224 - val_recall: 0.9250
# Epoch 4/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.1323 - recall: 0.9277 - val_loss: 0.1151 - val_recall: 0.9315
# Epoch 5/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.1281 - recall: 0.9302 - val_loss: 0.1076 - val_recall: 0.9385
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1221 - recall: 0.9335 - val_loss: 0.1038 - val_recall: 0.9373
# Epoch 7/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1184 - recall: 0.9361 - val_loss: 0.0995 - val_recall: 0.9407
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1162 - recall: 0.9384 - val_loss: 0.0972 - val_recall: 0.9381
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.1119 - recall: 0.9402 - val_loss: 0.0945 - val_recall: 0.9402
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.1095 - recall: 0.9425 - val_loss: 0.0908 - val_recall: 0.9474
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.1087 - recall: 0.9436 - val_loss: 0.0886 - val_recall: 0.9480
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1043 - recall: 0.9462 - val_loss: 0.0858 - val_recall: 0.9530
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1024 - recall: 0.9475 - val_loss: 0.0859 - val_recall: 0.9442
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1024 - recall: 0.9480 - val_loss: 0.0837 - val_recall: 0.9488
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0995 - recall: 0.9504 - val_loss: 0.0815 - val_recall: 0.9537
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0988 - recall: 0.9512 - val_loss: 0.0791 - val_recall: 0.9603
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0973 - recall: 0.9525 - val_loss: 0.0785 - val_recall: 0.9594
# Epoch 18/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0959 - recall: 0.9544 - val_loss: 0.0767 - val_recall: 0.9613
# Epoch 19/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0962 - recall: 0.9538 - val_loss: 0.0769 - val_recall: 0.9559
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.0936 - recall: 0.9552 - val_loss: 0.0750 - val_recall: 0.9632
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0922 - recall: 0.9571 - val_loss: 0.0735 - val_recall: 0.9632
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0921 - recall: 0.9573 - val_loss: 0.0721 - val_recall: 0.9657
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0917 - recall: 0.9581 - val_loss: 0.0730 - val_recall: 0.9599
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0915 - recall: 0.9583 - val_loss: 0.0704 - val_recall: 0.9665
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0887 - recall: 0.9600 - val_loss: 0.0707 - val_recall: 0.9621
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0892 - recall: 0.9587 - val_loss: 0.0682 - val_recall: 0.9690
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0882 - recall: 0.9609 - val_loss: 0.0682 - val_recall: 0.9670
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0863 - recall: 0.9614 - val_loss: 0.0675 - val_recall: 0.9675
# Epoch 29/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0863 - recall: 0.9622 - val_loss: 0.0665 - val_recall: 0.9694
# Epoch 30/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0858 - recall: 0.9630 - val_loss: 0.0653 - val_recall: 0.9715
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0859 - recall: 0.9621 - val_loss: 0.0655 - val_recall: 0.9690
# Epoch 32/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0844 - recall: 0.9635 - val_loss: 0.0645 - val_recall: 0.9692
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0839 - recall: 0.9639 - val_loss: 0.0633 - val_recall: 0.9723
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0842 - recall: 0.9637 - val_loss: 0.0634 - val_recall: 0.9704
# Epoch 35/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0825 - recall: 0.9648 - val_loss: 0.0626 - val_recall: 0.9739
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0837 - recall: 0.9652 - val_loss: 0.0625 - val_recall: 0.9722
# Epoch 37/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0814 - recall: 0.9662 - val_loss: 0.0616 - val_recall: 0.9725
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0822 - recall: 0.9660 - val_loss: 0.0605 - val_recall: 0.9756
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0808 - recall: 0.9667 - val_loss: 0.0602 - val_recall: 0.9753
# Epoch 40/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0813 - recall: 0.9665 - val_loss: 0.0604 - val_recall: 0.9743
# Epoch 41/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0807 - recall: 0.9673 - val_loss: 0.0599 - val_recall: 0.9739
# Epoch 42/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0803 - recall: 0.9665 - val_loss: 0.0592 - val_recall: 0.9748
# Epoch 43/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0792 - recall: 0.9681 - val_loss: 0.0586 - val_recall: 0.9763
# Epoch 44/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0786 - recall: 0.9679 - val_loss: 0.0582 - val_recall: 0.9771
# Epoch 45/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0792 - recall: 0.9695 - val_loss: 0.0583 - val_recall: 0.9738
# Epoch 46/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0775 - recall: 0.9684 - val_loss: 0.0573 - val_recall: 0.9770
# Epoch 47/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0768 - recall: 0.9696 - val_loss: 0.0566 - val_recall: 0.9794
# Epoch 48/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0781 - recall: 0.9696 - val_loss: 0.0572 - val_recall: 0.9763
# Epoch 49/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0774 - recall: 0.9694 - val_loss: 0.0562 - val_recall: 0.9781
# Epoch 50/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0773 - recall: 0.9701 - val_loss: 0.0565 - val_recall: 0.9776
# Epoch 51/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0774 - recall: 0.9696 - val_loss: 0.0553 - val_recall: 0.9782
# Epoch 52/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0757 - recall: 0.9706 - val_loss: 0.0548 - val_recall: 0.9794
# Epoch 53/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0744 - recall: 0.9710 - val_loss: 0.0551 - val_recall: 0.9784
# Epoch 54/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0763 - recall: 0.9705 - val_loss: 0.0546 - val_recall: 0.9788
# Epoch 55/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.0751 - recall: 0.9714 - val_loss: 0.0540 - val_recall: 0.9798
# Epoch 56/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0746 - recall: 0.9720 - val_loss: 0.0540 - val_recall: 0.9795
# Epoch 57/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0740 - recall: 0.9713 - val_loss: 0.0538 - val_recall: 0.9789
# Epoch 58/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0749 - recall: 0.9719 - val_loss: 0.0532 - val_recall: 0.9798
# Epoch 59/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0753 - recall: 0.9719 - val_loss: 0.0533 - val_recall: 0.9786
# Epoch 60/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0743 - recall: 0.9715 - val_loss: 0.0525 - val_recall: 0.9799
# Epoch 61/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0726 - recall: 0.9725 - val_loss: 0.0530 - val_recall: 0.9790
# Epoch 62/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0733 - recall: 0.9720 - val_loss: 0.0525 - val_recall: 0.9802
# Epoch 63/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0753 - recall: 0.9724 - val_loss: 0.0523 - val_recall: 0.9795
# Epoch 64/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0732 - recall: 0.9724 - val_loss: 0.0522 - val_recall: 0.9792
# Epoch 65/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0728 - recall: 0.9724 - val_loss: 0.0515 - val_recall: 0.9808
# Epoch 66/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0722 - recall: 0.9726 - val_loss: 0.0512 - val_recall: 0.9800
# Epoch 67/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0716 - recall: 0.9739 - val_loss: 0.0509 - val_recall: 0.9805
# Epoch 68/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0718 - recall: 0.9731 - val_loss: 0.0509 - val_recall: 0.9803
# Epoch 69/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0723 - recall: 0.9734 - val_loss: 0.0506 - val_recall: 0.9811
# Epoch 70/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0721 - recall: 0.9741 - val_loss: 0.0506 - val_recall: 0.9804
# Epoch 71/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0709 - recall: 0.9739 - val_loss: 0.0502 - val_recall: 0.9817
# Epoch 72/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0719 - recall: 0.9738 - val_loss: 0.0496 - val_recall: 0.9834
# Epoch 73/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0708 - recall: 0.9743 - val_loss: 0.0492 - val_recall: 0.9824
# Epoch 74/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0711 - recall: 0.9745 - val_loss: 0.0496 - val_recall: 0.9818
# Epoch 75/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0716 - recall: 0.9743 - val_loss: 0.0504 - val_recall: 0.9794
# Epoch 76/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0695 - recall: 0.9746 - val_loss: 0.0493 - val_recall: 0.9811
# Epoch 77/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0703 - recall: 0.9750 - val_loss: 0.0492 - val_recall: 0.9815
# Epoch 78/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0702 - recall: 0.9746 - val_loss: 0.0488 - val_recall: 0.9822
# Epoch 79/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0714 - recall: 0.9743 - val_loss: 0.0488 - val_recall: 0.9817
# Epoch 80/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0705 - recall: 0.9749 - val_loss: 0.0487 - val_recall: 0.9816
# Epoch 81/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0691 - recall: 0.9758 - val_loss: 0.0483 - val_recall: 0.9823
# Epoch 82/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0688 - recall: 0.9749 - val_loss: 0.0481 - val_recall: 0.9828
# Epoch 83/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0695 - recall: 0.9754 - val_loss: 0.0481 - val_recall: 0.9819
# Epoch 84/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0689 - recall: 0.9755 - val_loss: 0.0478 - val_recall: 0.9838
# Epoch 85/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0696 - recall: 0.9757 - val_loss: 0.0473 - val_recall: 0.9837
# Epoch 86/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0692 - recall: 0.9760 - val_loss: 0.0473 - val_recall: 0.9842
# Epoch 87/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0695 - recall: 0.9760 - val_loss: 0.0477 - val_recall: 0.9818
# Epoch 88/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0690 - recall: 0.9750 - val_loss: 0.0474 - val_recall: 0.9833
# Epoch 89/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0683 - recall: 0.9761 - val_loss: 0.0469 - val_recall: 0.9840
# Epoch 90/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0684 - recall: 0.9762 - val_loss: 0.0469 - val_recall: 0.9827
# Epoch 91/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0683 - recall: 0.9765 - val_loss: 0.0468 - val_recall: 0.9830
# Epoch 92/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0678 - recall: 0.9765 - val_loss: 0.0465 - val_recall: 0.9835
# Epoch 93/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0677 - recall: 0.9767 - val_loss: 0.0464 - val_recall: 0.9842
# Epoch 94/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0664 - recall: 0.9767 - val_loss: 0.0463 - val_recall: 0.9837
# Epoch 95/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0667 - recall: 0.9769 - val_loss: 0.0464 - val_recall: 0.9832
# Epoch 96/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0684 - recall: 0.9758 - val_loss: 0.0459 - val_recall: 0.9848
# Epoch 97/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0664 - recall: 0.9771 - val_loss: 0.0459 - val_recall: 0.9845
# Epoch 98/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0660 - recall: 0.9763 - val_loss: 0.0455 - val_recall: 0.9851
# Epoch 99/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0670 - recall: 0.9765 - val_loss: 0.0456 - val_recall: 0.9841
# Epoch 100/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0673 - recall: 0.9766 - val_loss: 0.0452 - val_recall: 0.9856

# %% [markdown]
# ## Training Loss and Val_Loss Visualization

# %%
history_df = pd.DataFrame(history.history)
plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(history_df.loc[:, ['loss', 'val_loss']])
plt.subplot(122)
plt.plot(history_df.loc[:, ['recall', 'val_recall']])
# Out:
# [<matplotlib.lines.Line2D at 0x7e228f45f880>,
#  <matplotlib.lines.Line2D at 0x7e228f45f8e0>]

# %%
plt.plot(history.history['loss'], label = "train")
plt.xlabel("Epochs")
plt.ylabel("Cost")
plt.title('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
eval_loss, eval_acc = model.evaluate(X_test, y_test) # 피드백 대로, Test_Set 분리 한 후, accuracy를 확인 한 결과, accuracy가 감소 했다
print(f"evaluation_acc = {eval_acc}")
print(f"evaluation_loss = {eval_loss}")
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0413 - recall: 0.8315
# evaluation_acc = 0.8505747318267822
# evaluation_loss = 0.04018441587686539

# %% [markdown]
# #Model Test

# %%
y_pred = model.predict(X_test)

print(y_pred[0])
print(y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# [7.553288e-05]
# 169876    0
# 127467    0
# 137900    0
# 21513     0
# 134700    0
#          ..
# 230213    0
# 275519    0
# 148273    0
# 77261     0
# 73202     0
# Name: Class, Length: 56962, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.plot(y_pred) #그래프모양 변경가능
plt.grid()
plt.show()

# %%
y_pred_class = np.where(y_pred > 0.5, 1 , 0)
y_pred_class=pd.DataFrame(y_pred_class)
y_pred_class.value_counts()
# Out:
# 0    56090
# 1      872
# Name: count, dtype: int64

# %% [markdown]
# #Recall

# %%
y_pred_class = np.where(y_pred > 0.5, 1 , 0) #0.5보다크면 1, 작으면 0
print(recall_score(y_test, y_pred_class))
# Out:
# 0.8505747126436781

# %% [markdown]
# #Confusion Matrix

# %%
plt.figure(figsize=(6, 4))
cm = confusion_matrix(y_test, y_pred_class, labels=[0,1], normalize='true')
plt.title("Confusion Matrix")
sns.heatmap(cm,
            annot=True,
            fmt=".2%",
            cmap="Blues",
            xticklabels=["0","1"],
            yticklabels=["0","1"])

print(classification_report(y_test, y_pred_class)) #y_test = y_actual
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56875
#            1       0.08      0.85      0.15        87
#
#     accuracy                           0.99     56962
#    macro avg       0.54      0.92      0.57     56962
# weighted avg       1.00      0.99      0.99     56962

# %% [markdown]
# # ROC Curve

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred_class)

plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# # AUC

# %%
print(roc_auc_score(y_test, y_pred_class))
# Out:
# 0.9182719717064546
